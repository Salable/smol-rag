# %%
# Note: Make sure to download the NLTK packages, if you haven't already
# nltk.download('punkt')
# nltk.download('punkt_tab')
# nltk.download('wordnet')

# %%
# Todo: Extract snippets, generate query and responses. Write to json.
import asyncio
import inspect
import re

import nltk
from aiolimiter import AsyncLimiter
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score

from app.definitions import INPUT_DOCS_DIR, EVALUATION_DATA_SET
from app.logger import set_logger, logger
from app.openai_llm import OpenAiLlm
from app.utilities import get_docs, read_file, create_file_if_not_exists, write_json



llm = OpenAiLlm()
llm_limiter = AsyncLimiter(max_rate=100, time_period=1)


async def rate_limited_get_completion(*args, **kwargs):
    async with llm_limiter:
        return await llm.get_completion(*args, **kwargs)


def calculate_bleu(reference_text: str, candidate_text: str) -> float:
    smoothing = SmoothingFunction().method1
    reference_tokens = nltk.word_tokenize(reference_text.lower())
    candidate_tokens = nltk.word_tokenize(candidate_text.lower())
    return sentence_bleu([reference_tokens], candidate_tokens, smoothing_function=smoothing)


def calculate_meteor(reference_text: str, candidate_text: str) -> float:
    reference_tokens = nltk.word_tokenize(reference_text.lower())
    candidate_tokens = nltk.word_tokenize(candidate_text.lower())
    return meteor_score([reference_tokens], candidate_tokens)


async def process_doc(doc, additional_context=None):
    logger.info(f"Processing document: {doc}")
    content = read_file(doc)
    raw_pull_quotes = await rate_limited_get_completion(inspect.cleandoc(f"""
        Extract up to three pull quote facts from this document. Each quote must be wrapped in a <pull-quote> tag.

        Remove all markdown formatting.
        Use no markdown formatting in your response.
        Pull quotes must be a minimum of ten words long.
        The quotes should be broadly related to the document content.
        Quotes must not be vague or unclear.
        It is of paramount importance that the quotes are accurate and use the precise copy of the document.
        Never make up quotes.
        Paraphrasing is permissible as a last resort.

        <content>
        {content}
        </content>

        Example One:
        <content>
        The study published by the National Oceanic and Atmospheric Administration revealed that the Arctic is warming nearly four times faster than the global average, resulting in unprecedented sea-ice loss and ecosystem disruption. Researchers warn that without immediate carbon emission reductions, the region could see ice-free summers as early as 2030.
        </content>
        <pull-quote>
        The Arctic is warming nearly four times faster than the global average, resulting in unprecedented sea-ice loss and ecosystem disruption.
        </pull-quote>
        <pull-quote>
        Without immediate carbon emission reductions, the region could see ice-free summers as early as 2030.
        </pull-quote>

        Example Two:
        <content>
        During its annual keynote, Horizon Dynamics unveiled the Helios X1, a lightweight electric aircraft capable of flying 500 miles on a single charge. CEO Maya Chen said the aircraft "reduces per-passenger emissions by 70 percent compared with regional jets" and will enter commercial service in 2027.
        </content>
        <pull-quote>
        the Helios X1, a lightweight electric aircraft capable of flying 500 miles on a single charge
        </pull-quote>
        <pull-quote>
        CEO Maya Chen said the aircraft "reduces per-passenger emissions by 70 percent compared with regional jets" and will enter commercial service in 2027
        </pull-quote>

        Example Three:
        <content>
        In her landmark address to Parliament on 18 June 1942, Noor Inayat Khan urged legislators to support the formation of a unified resistance council, stating, "We must stand together now, or we shall surely fall apart later." The speech galvanized cross-party backing and marked a turning point in wartime collaboration.
        </content>
        <pull-quote>
        In her landmark address to Parliament on 18 June 1942, Noor Inayat Khan urged legislators to support the formation of a unified resistance council
        </pull-quote>
        <pull-quote>
        Noor Inayat Khan urged legislators to support the formation of a unified resistance council, stating, "We must stand together now, or we shall surely fall apart later."
        </pull-quote>
    """))

    pull_quotes = [
        match.strip()
        for match in re.findall(r"<pull-quote>\s*(.*?)\s*</pull-quote>", raw_pull_quotes, flags=re.DOTALL)
    ]

    logger.info(f"Extracted {len(pull_quotes)} pull quotes from {doc}")
    pull_quote_tasks = [process_pull_quote(pull_quote, content, additional_context) for pull_quote in pull_quotes]
    results = await asyncio.gather(*pull_quote_tasks)
    return results


async def process_pull_quote(pull_quote, content, additional_context=None):
    logger.info(f"Processing pull quote: {pull_quote}")
    prompt = inspect.cleandoc(f"""
        Ask a question that relates to the pull quote and an expected response that you might expect from a rag that contains this information

        The question and response must directly target this pull quote.

        Use no markdown formatting in your response
        The question and response should each be on a single line:
         - the question must be on the first line
         - the response must be on the second line
        respond with only the question and response

        <content>
        {content}
        </content>

        <pull-quote>
        {pull_quote}
        </pull-quote>
    """)

    if additional_context is not None:
        prompt += f"\n\n<additional-context>\n{additional_context}\n</additional-context>"

    raw_query_response = await rate_limited_get_completion(prompt)

    clean_result = [line.strip() for line in re.sub(r'\n+', '\n', raw_query_response).strip().split('\n')]
    if len(clean_result) != 2:
        logger.info(f"Pull quote skipped due to unexpected answer format: {pull_quote}")
        return None
    (query, response) = clean_result
    bleu = calculate_bleu(pull_quote, response)
    meteor = calculate_meteor(pull_quote, response)
    if bleu >= 0.85:
        logger.info(f"Pull quote skipped due to high BLEU score (likely identical): {pull_quote}")
        return None
    # Note: chuck out results that match too closely they're likely identical to the initial query
    logger.info(f"Generated query/response pair for pull quote (BLEU={bleu:.2f}, METEOR={meteor:.2f})")
    return {
        "pull_quote": pull_quote,
        "query": query,
        "response": response,
        "bleu": bleu,
        "meteor": meteor
    }



async def generate():
    logger.info("Starting test set generation process.")
    logger.info(f"INPUT_DOCS_DIR: {INPUT_DOCS_DIR}")
    logger.info(f"EVALUATION_DATA_SET: {EVALUATION_DATA_SET}")

    create_file_if_not_exists(EVALUATION_DATA_SET, "")
    docs = get_docs(INPUT_DOCS_DIR)
    logger.info(f"Found {len(docs)} documents to process.")

    process_doc_tasks = [process_doc(doc) for doc in docs]
    results = await asyncio.gather(*process_doc_tasks)
    clean_results = [result for sublist in results for result in sublist if result is not None]
    logger.info(f"Writing {len(clean_results)} query/response pairs to {EVALUATION_DATA_SET}")
    write_json(EVALUATION_DATA_SET, clean_results)
    logger.info("Test set generation completed successfully.")

# %%
set_logger("generate_test_set.log")
await generate()

# %%
import asyncio
import inspect

from app.definitions import EVALUATION_DATA_SET
from app.openai_llm import OpenAiLlm
from app.smol_rag import SmolRag
from app.utilities import get_json
from app.logger import logger

rag = SmolRag()
llm = OpenAiLlm()


async def evaluate():
    data_set = get_json(EVALUATION_DATA_SET)
    logger.info(f"Loaded dataset from {EVALUATION_DATA_SET} with {len(data_set)} items.")

    query_tasks = [rag.mix_query(row["query"]) for row in data_set]
    responses = await asyncio.gather(*query_tasks)
    logger.info("Completed generating responses for all queries.")

    tasks = []
    for (response, row) in zip(responses, data_set):
        prompt = inspect.cleandoc(f"""
            Does the <response> accurately answer the <query> in relation to the <source>?

            Response parameters:
            You must answer with either "yes" or "no"
            There must be no other content in your response

            <query>
            {row["query"]}
            </query>

            <response>
            {response}
            </response>

            <source>
            {row["pull_quote"]}
            </source>
        """)

        tasks.extend([get_review(prompt, row["query"]) for _ in range(3)])

    results = await asyncio.gather(*tasks)

    score = sum(results) / len(results)
    logger.info(f"Evaluation completed. Final accuracy score: {score:.3f}")

    return score

async def get_review(prompt, query):
    tasks = [
        rag.rate_limited_get_completion(prompt, use_cache=False)
        for _ in range(3)
    ]
    logger.info(f"Evaluating accuracy for query: {query!r}")  # <-- Logging evaluation step
    results = await asyncio.gather(*tasks)

    responses = [
        1 if result == "yes" else 0
        for result in results
        if result in ("yes", "no")
    ]

    accuracy = 1 if sum(responses) / len(responses) > 0.5 else 0
    logger.info(
        f"Evaluation result for query {query!r}: {sum(responses)}/{len(responses)} votes yes --> {accuracy}")

    return accuracy
# Out:
# INFO:nano-vectordb:Load (226, 1536) data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': '/Users/orderandchaos/code/salable-smol-rag/app/data/embeddings_db.json'} 226 data
# INFO:nano-vectordb:Load (935, 1536) data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': '/Users/orderandchaos/code/salable-smol-rag/app/data/entities_db.json'} 935 data
# INFO:nano-vectordb:Load (997, 1536) data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': '/Users/orderandchaos/code/salable-smol-rag/app/data/relationships_db.json'} 997 data
# INFO:mini-rag:Knowledge graph loaded from /Users/orderandchaos/code/salable-smol-rag/app/data/kg_db.graphml

# %%
set_logger("evaluate_test_set.log")
await evaluate()
# Out:
# INFO:mini-rag:Loaded dataset from /Users/orderandchaos/code/salable-smol-rag/app/evaluation/test_sets/evaluation_data_set.json with 176 items.
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Processed high/low level keywords for mixed KG query.
# INFO:mini-rag:Found 5 low-level keywords.
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New embedding
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Getting node Authentication
# INFO:mini-rag:Getting node 401
# INFO:mini-rag:Getting node apiKey
# INFO:mini-rag:Getting node Request Three D Secure
# INFO:mini-rag:Getting node Verification Code
# INFO:mini-rag:Getting node Secure Password
# INFO:mini-rag:Getting node 403
# INFO:mini-rag:Getting node Accept Invitation
# INFO:mini-rag:Getting node License check
# INFO:mini-rag:Getting node Session Token
# INFO:mini-rag:Getting node session-token
# INFO:mini-rag:Getting node API Key
# INFO:mini-rag:Getting node RBAC
# INFO:mini-rag:Getting node signature check
# INFO:mini-rag:Getting node Stripe Onboarding
# INFO:mini-rag:Getting node Creating a Session Token
# INFO:mini-rag:Getting node Error Handling
# INFO:mini-rag:Getting node StripeThreeDSecureUsage
# INFO:mini-rag:Getting node license
# INFO:mini-rag:Getting node public key
# INFO:mini-rag:Getting node verifyLicenseCheck
# INFO:mini-rag:Getting node ECDSA
# INFO:mini-rag:Getting node User ID
# INFO:mini-rag:Getting node YOUR_SESSION_TOKEN
# INFO:mini-rag:Getting node verify
# INFO:mini-rag:Getting node decrementSubscriptionSeats
# INFO:mini-rag:Getting node API Key
# INFO:mini-rag:Getting node Metadata
# INFO:mini-rag:Getting node your-license-uuid
# INFO:mini-rag:Getting node getGrantee
# INFO:mini-rag:Getting node Cancellation Button
# INFO:mini-rag:Getting node SalableCancellationButton
# INFO:mini-rag:Getting node sessionToken
# INFO:mini-rag:Getting node Checkout Link
# INFO:mini-rag:Getting node Quick Start
# INFO:mini-rag:Getting node Get Product Features
# INFO:mini-rag:Getting node Cancel a Subscription
# INFO:mini-rag:Getting node signature check
# INFO:mini-rag:Getting node SalablePricingTable
# INFO:mini-rag:Getting node createSession
# INFO:mini-rag:Getting node Authentication
# INFO:mini-rag:Getting node Invoices Web Component
# INFO:mini-rag:Getting node Card
# INFO:mini-rag:Getting node web-components:invoices
# INFO:mini-rag:Getting node JavaScript
# INFO:mini-rag:Getting node Add Payment Integration
# INFO:mini-rag:Getting node ECDSA Encryption and Signatures
# INFO:mini-rag:Getting node salable-invoices
# INFO:mini-rag:Getting node Salable
# INFO:mini-rag:Getting node Subscription UUID
# INFO:mini-rag:Getting node signature
# INFO:mini-rag:Getting node Invitation Email
# INFO:mini-rag:Getting node capabilities
# INFO:mini-rag:Getting node SHA-256
# INFO:mini-rag:Getting node getLicenseByUuid
# INFO:mini-rag:Getting node StripeCard
# INFO:mini-rag:Getting node Create License
# INFO:mini-rag:Getting node Copy Icon
# INFO:mini-rag:Getting node uuid
# INFO:mini-rag:Getting node Name
# INFO:mini-rag:Getting node granteeId
# INFO:mini-rag:Getting node Salable Cancellation Button
# INFO:mini-rag:Getting node Grantee
# INFO:mini-rag:Getting node API Documentation
# INFO:mini-rag:Getting node api.salable.app
# INFO:mini-rag:Getting node Scope
# INFO:mini-rag:Getting node importPublicKey
# INFO:mini-rag:Getting node Salable Account
# INFO:mini-rag:Getting node Licenses
# INFO:mini-rag:Getting node public key
# INFO:mini-rag:Getting node getCurrentLicenseUsage
# INFO:mini-rag:Getting node Join an Organisation
# INFO:mini-rag:Getting node Setup
# INFO:mini-rag:Getting node SalableInvoices
# INFO:mini-rag:Getting node Salable API
# INFO:mini-rag:Getting node cURL
# INFO:mini-rag:Extracted 12 excerpts for low-level entities.
# INFO:mini-rag:Getting edge ('API Key', 'Authentication')
# INFO:mini-rag:Getting edge ('Authentication', 'Quick Start')
# INFO:mini-rag:Getting edge ('Licenses', 'apiKey')
# INFO:mini-rag:Getting edge ('Cancel a Subscription', 'apiKey')
# INFO:mini-rag:Getting edge ('api.salable.app', 'apiKey')
# INFO:mini-rag:Getting edge ('Get Product Features', 'apiKey')
# INFO:mini-rag:Getting edge ('apiKey', 'getLicenseByUuid')
# INFO:mini-rag:Getting edge ('apiKey', 'decrementSubscriptionSeats')
# INFO:mini-rag:Getting edge ('apiKey', 'getCurrentLicenseUsage')
# INFO:mini-rag:Getting edge ('Card', 'Request Three D Secure')
# INFO:mini-rag:Getting edge ('Salable', 'Verification Code')
# INFO:mini-rag:Getting edge ('Name', 'Secure Password')
# INFO:mini-rag:Getting edge ('Accept Invitation', 'Join an Organisation')
# INFO:mini-rag:Getting edge ('Accept Invitation', 'Invitation Email')
# INFO:mini-rag:Getting edge ('License check', 'getGrantee')
# INFO:mini-rag:Getting edge ('License check', 'capabilities')
# INFO:mini-rag:Getting edge ('Salable API', 'Session Token')
# INFO:mini-rag:Getting edge ('Cancellation Button', 'Session Token')
# INFO:mini-rag:Getting edge ('Invoices Web Component', 'Session Token')
# INFO:mini-rag:Getting edge ('JavaScript', 'Session Token')
# INFO:mini-rag:Getting edge ('Session Token', 'cURL')
# INFO:mini-rag:Getting edge ('Scope', 'Session Token')
# INFO:mini-rag:Getting edge ('Metadata', 'Session Token')
# INFO:mini-rag:Getting edge ('Session Token', 'web-components:invoices')
# INFO:mini-rag:Getting edge ('Salable Cancellation Button', 'session-token')
# INFO:mini-rag:Getting edge ('SalableCancellationButton', 'session-token')
# INFO:mini-rag:Getting edge ('salable-invoices', 'session-token')
# INFO:mini-rag:Getting edge ('session-token', 'sessionToken')
# INFO:mini-rag:Getting edge ('createSession', 'session-token')
# INFO:mini-rag:Getting edge ('SalablePricingTable', 'session-token')
# INFO:mini-rag:Getting edge ('API Key', 'Salable')
# INFO:mini-rag:Getting edge ('API Key', 'Salable Account')
# INFO:mini-rag:Getting edge ('API Key', 'Checkout Link')
# INFO:mini-rag:Getting edge ('API Documentation', 'API Key')
# INFO:mini-rag:Getting edge ('API Key', 'Copy Icon')
# INFO:mini-rag:Getting edge ('API Key', 'Setup')
# INFO:mini-rag:Getting edge ('ECDSA Encryption and Signatures', 'signature check')
# INFO:mini-rag:Getting edge ('public key', 'signature check')
# INFO:mini-rag:Getting edge ('Add Payment Integration', 'Stripe Onboarding')
# INFO:mini-rag:Getting edge ('Creating a Session Token', 'Salable API')
# INFO:mini-rag:Getting edge ('Creating a Session Token', 'Subscription UUID')
# INFO:mini-rag:Getting edge ('StripeCard', 'StripeThreeDSecureUsage')
# INFO:mini-rag:Getting edge ('granteeId', 'license')
# INFO:mini-rag:Getting edge ('license', 'uuid')
# INFO:mini-rag:Getting edge ('Create License', 'license')
# INFO:mini-rag:Getting edge ('license', 'your-license-uuid')
# INFO:mini-rag:Getting edge ('capabilities', 'verifyLicenseCheck')
# INFO:mini-rag:Getting edge ('importPublicKey', 'verifyLicenseCheck')
# INFO:mini-rag:Getting edge ('signature', 'verifyLicenseCheck')
# INFO:mini-rag:Getting edge ('ECDSA', 'SHA-256')
# INFO:mini-rag:Getting edge ('Grantee', 'User ID')
# INFO:mini-rag:Getting edge ('SalableInvoices', 'YOUR_SESSION_TOKEN')
# INFO:mini-rag:Extracted 42 relationships from low-level entities.
# INFO:mini-rag:Low-level dataset: 25 entities, 42 relationships extracted.
# INFO:mini-rag:Found 3 high-level keywords.
# INFO:mini-rag:New embedding
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Getting edge ('CreateSession', 'sessionToken')
# INFO:mini-rag:Getting edge ('session-token', 'sessionToken')
# INFO:mini-rag:Getting edge ('createSession', 'session-token')
# INFO:mini-rag:Getting edge ('api.salable.app', 'sessionToken')
# INFO:mini-rag:Getting edge ('Salable API', 'Session Token')
# INFO:mini-rag:Getting edge ('checkout', 'sessionToken')
# INFO:mini-rag:Getting edge ('Salable Cancellation Button', 'session-token')
# INFO:mini-rag:Getting edge ('JavaScript', 'Session Token')
# INFO:mini-rag:Getting edge ('SalablePricingTable', 'session-token')
# INFO:mini-rag:Getting edge ('SalablePricingTable', 'sessionToken')
# INFO:mini-rag:Getting edge ('salable-invoices', 'session-token')
# INFO:mini-rag:Getting edge ('globalGranteeId', 'sessionToken')
# INFO:mini-rag:Getting edge ('Scope', 'Session Token')
# INFO:mini-rag:Getting edge ('SalableInvoices', 'YOUR_SESSION_TOKEN')
# INFO:mini-rag:Getting edge ('SalableCheckout', 'UR_SESSION_TOKEN')
# INFO:mini-rag:Getting edge ('Session Token', 'web-components:invoices')
# INFO:mini-rag:Getting edge ('Metadata', 'Session Token')
# INFO:mini-rag:Getting edge ('Session Token', 'cURL')
# INFO:mini-rag:Getting edge ('SalableCancellationButton', 'session-token')
# INFO:mini-rag:Getting edge ('Creating a Session Token', 'Subscription UUID')
# INFO:mini-rag:Getting edge ('Cancellation Button', 'Session Token')
# INFO:mini-rag:Getting edge ('Invoices Web Component', 'Session Token')
# INFO:mini-rag:Getting edge ('SalableInvoices', 'sessionToken')
# INFO:mini-rag:Getting edge ('Creating a Session Token', 'Salable API')
# INFO:mini-rag:Getting edge ('SalableCancellationButton', 'sessionToken')
# INFO:mini-rag:Getting node Salable API
# INFO:mini-rag:Getting node Session Token
# INFO:mini-rag:Getting node SalablePricingTable
# INFO:mini-rag:Getting node sessionToken
# INFO:mini-rag:Getting node Creating a Session Token
# INFO:mini-rag:Getting node api.salable.app
# INFO:mini-rag:Getting node SalableInvoices
# INFO:mini-rag:Getting node session-token
# INFO:mini-rag:Getting node SalableCancellationButton
# INFO:mini-rag:Getting node Cancellation Button
# INFO:mini-rag:Getting node CreateSession
# INFO:mini-rag:Getting node cURL
# INFO:mini-rag:Getting node YOUR_SESSION_TOKEN
# INFO:mini-rag:Getting node checkout
# INFO:mini-rag:Getting node Salable Cancellation Button
# INFO:mini-rag:Getting node Invoices Web Component
# INFO:mini-rag:Getting node salable-invoices
# INFO:mini-rag:Getting node globalGranteeId
# INFO:mini-rag:Getting node Metadata
# INFO:mini-rag:Getting node createSession
# INFO:mini-rag:Getting node JavaScript
# INFO:mini-rag:Getting node Scope
# INFO:mini-rag:Getting node web-components:invoices
# INFO:mini-rag:Getting node SalableCheckout
# INFO:mini-rag:Getting node UR_SESSION_TOKEN
# INFO:mini-rag:Getting node Subscription UUID
# INFO:mini-rag:Extracted 26 entities from relationships.
# INFO:mini-rag:High-level dataset: 25 relationships, 26 entities extracted.
# INFO:mini-rag:New embedding
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:KG query context built with 51 entities, 67 relationships, and 23 excerpts.
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Query cache hit
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:New query
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:mini-rag:Processed high/low level keywords for mixed KG query.
# INFO:mini-rag:Found 5 low-level keywords.
# INFO:mini-rag:Embedding cache hit
# INFO:mini-rag:Getting node Setup
# INFO:mini-rag:Getting node Quick Start
# INFO:mini-rag:Getting node Get Started Free
# INFO:mini-rag:Getting node Join an Organisation
# INFO:mini-rag:Getting node Stripe Onboarding
# INFO:mini-rag:Getting node Starting Balance
# INFO:mini-rag:Getting node Invitation Process
# INFO:mini-rag:Getting node Granular Approach
# INFO:mini-rag:Getting node Assign Values Tab
# INFO:mini-rag:Getting node Account Creation
# INFO:mini-rag:Getting node Invite Member Button
# INFO:mini-rag:Getting node Define Custom Elements
# INFO:mini-rag:Getting node Salable Way
# INFO:mini-rag:Getting node Email Address
# INFO:mini-rag:Getting node Creating a Session Token
# INFO:mini-rag:Getting node Accept Invitation
# INFO:mini-rag:Getting node Create a Product
# INFO:mini-rag:Getting node startTime
# INFO:mini-rag:Getting node Trial Period
# INFO:mini-rag:Getting node Free Plan
# INFO:mini-rag:Getting node Create Session
# INFO:mini-rag:Getting node Basic Plan
# INFO:mini-rag:Getting node Create Feature
# INFO:mini-rag:Getting node checkoutCreateSubscription
# INFO:mini-rag:Getting node Get One Plan
# INFO:mini-rag:Getting node CheckoutCreateSubscriptionRequest
# INFO:mini-rag:Getting node Team Member
# INFO:mini-rag:Getting node API Key
# INFO:mini-rag:Getting node Payment Integration
# INFO:mini-rag:Getting node Remove Seats
# INFO:mini-rag:Getting node Organisation Details
# INFO:mini-rag:Getting node Add Seats
# INFO:mini-rag:Getting node Authentication
# INFO:mini-rag:Getting node Team Tab
# INFO:mini-rag:Getting node Add Payment Integration
# INFO:mini-rag:Getting node Export CSV
# INFO:mini-rag:Getting node PricingTable
# INFO:mini-rag:Getting node Invite Your Team to Salable
# INFO:mini-rag:Getting node Email Address
# INFO:mini-rag:Getting node Add Currencies
# INFO:mini-rag:Getting node Salable
# INFO:mini-rag:Getting node Subscription UUID
# INFO:mini-rag:Getting node CreateSessionInput
# INFO:mini-rag:Getting node salable-checkout
# INFO:mini-rag:Getting node Invitation Email
# INFO:mini-rag:Getting node Features
# INFO:mini-rag:Getting node Trial Period
# INFO:mini-rag:Getting node Features Tab
# INFO:mini-rag:Getting node Accept Invitation
# INFO:mini-rag:Getting node options
# INFO:mini-rag:Getting node Invite Member Button
# INFO:mini-rag:Getting node Default Pricing Table
# INFO:mini-rag:Getting node Code Sample
# INFO:mini-rag:Getting node Bespoke Plan
# INFO:mini-rag:Getting node Capabilities Tab
# INFO:mini-rag:Getting node Usage
# INFO:mini-rag:Getting node CheckoutCreateSubscriptionResponse
# INFO:mini-rag:Getting node plan object
# INFO:mini-rag:Getting node Checkout
# INFO:mini-rag:Getting node Free Plan
# INFO:mini-rag:Getting node Edit Icon
# INFO:mini-rag:Getting node planUuid
# INFO:mini-rag:Getting node SessionScope.PricingTable
# INFO:mini-rag:Getting node Join an Organisation
# INFO:mini-rag:Getting node Assign Values Tab
# INFO:mini-rag:Getting node Capabilities
# INFO:mini-rag:Getting node Salable API
# INFO:mini-rag:Extracted 14 excerpts for low-level entities.
# INFO:mini-rag:Getting edge ('Payment Integration', 'Setup')
# INFO:mini-rag:Getting edge ('API Key', 'Setup')
# INFO:mini-rag:Getting edge ('Authentication', 'Quick Start')
# INFO:mini-rag:Getting edge ('Get Started Free', 'Salable')
# INFO:mini-rag:Getting edge ('Invite Your Team to Salable', 'Join an Organisation')
# INFO:mini-rag:Getting edge ('Accept Invitation', 'Join an Organisation')
# INFO:mini-rag:Getting edge ('Add Payment Integration', 'Stripe Onboarding')
# INFO:mini-rag:Getting edge ('Invitation Process', 'Team Member')
# INFO:mini-rag:Getting edge ('Granular Approach', 'Salable')
# INFO:mini-rag:Getting edge ('Capabilities', 'Granular Approach')
# INFO:mini-rag:Getting edge ('Assign Values Tab', 'Free Plan')
# INFO:mini-rag:Getting edge ('Account Creation', 'Organisation Details')
# INFO:mini-rag:Getting edge ('Invite Member Button', 'Team Tab')
# INFO:mini-rag:Getting edge ('Email Address', 'Invite Member Button')
# INFO:mini-rag:Getting edge ('Define Custom Elements', 'salable-checkout')
# INFO:mini-rag:Getting edge ('Bespoke Plan', 'Salable Way')
# INFO:mini-rag:Getting edge ('Creating a Session Token', 'Salable API')
# INFO:mini-rag:Getting edge ('Creating a Session Token', 'Subscription UUID')
# INFO:mini-rag:Getting edge ('Accept Invitation', 'Invitation Email')
# INFO:mini-rag:Getting edge ('Add Currencies', 'Create a Product')
# INFO:mini-rag:Getting edge ('Free Plan', 'Trial Period')
# INFO:mini-rag:Getting edge ('Default Pricing Table', 'Free Plan')
# INFO:mini-rag:Getting edge ('Capabilities Tab', 'Free Plan')
# INFO:mini-rag:Getting edge ('Edit Icon', 'Free Plan')
# INFO:mini-rag:Getting edge ('Add Seats', 'Free Plan')
# INFO:mini-rag:Getting edge ('Free Plan', 'Remove Seats')
# INFO:mini-rag:Getting edge ('Free Plan', 'Usage')
# INFO:mini-rag:Getting edge ('Create Session', 'Salable')
# INFO:mini-rag:Getting edge ('Code Sample', 'Create Session')
# INFO:mini-rag:Getting edge ('Create Session', 'CreateSessionInput')
# INFO:mini-rag:Getting edge ('Create Session', 'SessionScope.PricingTable')
# INFO:mini-rag:Getting edge ('Basic Plan', 'Export CSV')
# INFO:mini-rag:Getting edge ('Create Feature', 'Features')
# INFO:mini-rag:Getting edge ('Create Feature', 'Features Tab')
# INFO:mini-rag:Getting edge ('Checkout', 'checkoutCreateSubscription')
# INFO:mini-rag:Getting edge ('PricingTable', 'checkoutCreateSubscription')
# INFO:mini-rag:Getting edge ('CheckoutCreateSubscriptionRequest', 'checkoutCreateSubscription')
# INFO:mini-rag:Getting edge ('CheckoutCreateSubscriptionResponse', 'checkoutCreateSubscription')
# INFO:mini-rag:Getting edge ('Get One Plan', 'Salable')
# INFO:mini-rag:Getting edge ('Get One Plan', 'planUuid')
# INFO:mini-rag:Getting edge ('Code Sample', 'Get One Plan')
# INFO:mini-rag:Getting edge ('Get One Plan', 'options')
# INFO:mini-rag:Getting edge ('Get One Plan', 'plan object')
# INFO:mini-rag:Extracted 43 relationships from low-level entities.
# INFO:mini-rag:Low-level dataset: 25 entities, 43 relationships extracted.
# INFO:mini-rag:Found 3 high-level keywords.
# INFO:mini-rag:Embedding cache hit
# INFO:mini-rag:Getting edge ('Capabilities', 'Trash Can Icon')
# INFO:mini-rag:Getting edge ('member', 'owner')
# INFO:mini-rag:Getting edge ('Product', 'status')
# INFO:mini-rag:Getting edge ('proration', 'proration_details')
# INFO:mini-rag:Getting edge ('decrement', 'removeSeats')
# INFO:mini-rag:Getting edge ('decrementSubscriptionSeats', 'proration')
# INFO:mini-rag:Getting edge ('Salable API', 'Version')
# INFO:mini-rag:Getting edge ('decrement', 'decrementSubscriptionSeats')
# INFO:mini-rag:Getting edge ('DecrementSubscriptionSeats', 'Subscription')
# INFO:mini-rag:Getting edge ('change Subscription plan endpoint', "update Subscription's plan endpoint")
# INFO:mini-rag:Getting edge ('Subscriptions', 'decrementSubscriptionSeats')
# INFO:mini-rag:Getting edge ('capability', 'status')
# INFO:mini-rag:Getting edge ('Remove Subscription Seats', 'decrement')
# INFO:mini-rag:Getting edge ('Sample Product', 'status')
# INFO:mini-rag:Getting edge ('License', 'Suspend License')
# INFO:mini-rag:Getting edge ('Salable', 'import statement')
# INFO:mini-rag:Getting edge ('ProductPricingTable', 'status')
# INFO:mini-rag:Getting edge ('Licenses', 'SalableUnknownError')
# INFO:mini-rag:Getting edge ('removeSeats', 'subscription management')
# INFO:mini-rag:Getting edge ('SalableCheckout', 'dynamic')
# INFO:mini-rag:Getting edge ('Salable', 'removeSeats')
# INFO:mini-rag:Getting edge ('Data', 'Discountable')
# INFO:mini-rag:Getting edge ('Feature Description', 'Updated At')
# INFO:mini-rag:Getting edge ('Licenses', 'removeSeats')
# INFO:mini-rag:Getting edge ('Custom Elements Definition', 'Salable Web Components library')
# INFO:mini-rag:Getting node Salable
# INFO:mini-rag:Getting node removeSeats
# INFO:mini-rag:Getting node import statement
# INFO:mini-rag:Getting node Product
# INFO:mini-rag:Getting node status
# INFO:mini-rag:Getting node ProductPricingTable
# INFO:mini-rag:Getting node Licenses
# INFO:mini-rag:Getting node SalableUnknownError
# INFO:mini-rag:Getting node Sample Product
# INFO:mini-rag:Getting node capability
# INFO:mini-rag:Getting node DecrementSubscriptionSeats
# INFO:mini-rag:Getting node Subscription
# INFO:mini-rag:Getting node Salable API
# INFO:mini-rag:Getting node Version
# INFO:mini-rag:Getting node License
# INFO:mini-rag:Getting node Suspend License
# INFO:mini-rag:Getting node member
# INFO:mini-rag:Getting node owner
# INFO:mini-rag:Getting node Data
# INFO:mini-rag:Getting node Discountable
# INFO:mini-rag:Getting node Feature Description
# INFO:mini-rag:Getting node Updated At
# INFO:mini-rag:Getting node decrementSubscriptionSeats
# INFO:mini-rag:Getting node proration
# INFO:mini-rag:Getting node decrement
# INFO:mini-rag:Getting node Subscriptions
# INFO:mini-rag:Getting node Remove Subscription Seats
# INFO:mini-rag:Getting node Capabilities
# INFO:mini-rag:Getting node Trash Can Icon
# INFO:mini-rag:Getting node subscription management
# INFO:mini-rag:Getting node proration_details
# INFO:mini-rag:Getting node SalableCheckout
# INFO:mini-rag:Getting node dynamic
# INFO:mini-rag:Getting node Custom Elements Definition
# INFO:mini-rag:Getting node Salable Web Components library
# INFO:mini-rag:Getting node change Subscription plan endpoint
# INFO:mini-rag:Getting node update Subscription's plan endpoint
# INFO:mini-rag:Extracted 16 entities from relationships.
# INFO:mini-rag:High-level dataset: 25 relationships, 16 entities extracted.
# INFO:mini-rag:Embedding cache hit
# INFO:mini-rag:KG query context built with 41 entities, 68 relationships, and 26 excerpts.
# INFO:mini-rag:Processed high/low level keywords for mixed KG query.
# INFO:mini-rag:Found 4 low-level keywords.
# INFO:mini-rag:Embedding cache hit
# INFO:mini-rag:Getting node license
# INFO:mini-rag:Getting node updateLicense
# INFO:mini-rag:Getting node License
# INFO:mini-rag:Getting node LicenseByPurchaser
# INFO:mini-rag:Getting node License Type Section
# INFO:mini-rag:Getting node Evaluation License
# INFO:mini-rag:Getting node license object
# INFO:mini-rag:Getting node Create License
# INFO:mini-rag:Getting node License check
# INFO:mini-rag:Getting node Evaluation Licenses
# INFO:mini-rag:Getting node CreateAdhocLicenseInput
# INFO:mini-rag:Getting node cancelLicense
# INFO:mini-rag:Getting node License Usage Record
# INFO:mini-rag:Getting node Cancel License
# INFO:mini-rag:Getting node Licenses
# INFO:mini-rag:Getting node Licenses Endpoint
# INFO:mini-rag:Getting node updateLicenseUsage
# INFO:mini-rag:Getting node licenses
# INFO:mini-rag:Getting node UpdateLicenseUsage
# INFO:mini-rag:Getting node License Object
# INFO:mini-rag:Getting node licenses object
# INFO:mini-rag:Getting node LicenseCheck
# INFO:mini-rag:Getting node Grantee System
# INFO:mini-rag:Getting node Get Licenses for a Purchaser
# INFO:mini-rag:Getting node Grantee
# INFO:mini-rag:Getting node Salable Dashboard
# INFO:mini-rag:Getting node Subscription
# INFO:mini-rag:Getting node your-license-uuid
# INFO:mini-rag:Getting node LicenseCreateRequest
# INFO:mini-rag:Getting node metadata
# INFO:mini-rag:Getting node Plan
# INFO:mini-rag:Getting node VersionHeader
# INFO:mini-rag:Getting node getLicenseCheck
# INFO:mini-rag:Getting node Expiration Date Parameter
# INFO:mini-rag:Getting node LicenseByPurchaser
# INFO:mini-rag:Getting node cancelLicenses
# INFO:mini-rag:Getting node CursorPaginationLicensesResponse
# INFO:mini-rag:Getting node Grantee
# INFO:mini-rag:Getting node incrementSubscriptionSeats
# INFO:mini-rag:Getting node CreateManyLicensesRequest
# INFO:mini-rag:Getting node SalableResponseError
# INFO:mini-rag:Getting node Licenses
# INFO:mini-rag:Getting node Parameters
# INFO:mini-rag:Getting node Create License Sidebar
# INFO:mini-rag:Getting node Update Many Licenses
# INFO:mini-rag:Getting node Get One License
# INFO:mini-rag:Getting node Capabilities
# INFO:mini-rag:Getting node Bespoke Plans
# INFO:mini-rag:Getting node apiKey
# INFO:mini-rag:Getting node getGrantee
# INFO:mini-rag:Getting node License
# INFO:mini-rag:Getting node cancelLicense
# INFO:mini-rag:Getting node Product
# INFO:mini-rag:Getting node getLicensesByGranteeId
# INFO:mini-rag:Getting node Salable
# INFO:mini-rag:Getting node updateLicense
# INFO:mini-rag:Getting node update
# INFO:mini-rag:Getting node Suspend License
# INFO:mini-rag:Getting node granteeId
# INFO:mini-rag:Getting node CreateAdhocLicenseInput
# INFO:mini-rag:Getting node licenses.getForPurchaser
# INFO:mini-rag:Getting node status
# INFO:mini-rag:Getting node cancel License API Endpoint
# INFO:mini-rag:Getting node cancel License Documentation
# INFO:mini-rag:Getting node UpdateLicenseUsageOptions
# INFO:mini-rag:Getting node getCount
# INFO:mini-rag:Getting node getLicensesByPurchaser
# INFO:mini-rag:Getting node LicenseUuidPathParam
# INFO:mini-rag:Getting node getOne
# INFO:mini-rag:Getting node Standard Plans
# INFO:mini-rag:Getting node Licensee Email
# INFO:mini-rag:Getting node signature
# INFO:mini-rag:Getting node capabilities
# INFO:mini-rag:Getting node getLicenseByUuid
# INFO:mini-rag:Getting node Grantee ID
# INFO:mini-rag:Getting node endTime
# INFO:mini-rag:Getting node licenses
# INFO:mini-rag:Getting node Get All Licenses
# INFO:mini-rag:Getting node Product & Plan
# INFO:mini-rag:Getting node Update License
# INFO:mini-rag:Getting node LicenseUpdateRequest
# INFO:mini-rag:Getting node Update License Usage
# INFO:mini-rag:Getting node User ID
# INFO:mini-rag:Getting node SalableValidationError
# INFO:mini-rag:Getting node Licenses Endpoint
# INFO:mini-rag:Getting node Create New License
# INFO:mini-rag:Getting node Left-Hand Menu
# INFO:mini-rag:Getting node Get License Usage
# INFO:mini-rag:Getting node TypeScript Code Sample
# INFO:mini-rag:Getting node Product Page
# INFO:mini-rag:Getting node Get Licenses for a Grantee ID
# INFO:mini-rag:Getting node removeSeats
# INFO:mini-rag:Getting node LicenseCount
# INFO:mini-rag:Getting node uuid
# INFO:mini-rag:Getting node getLicensesCount
# INFO:mini-rag:Getting node Board ID
# INFO:mini-rag:Getting node License Object
# INFO:mini-rag:Getting node Coming Soon Plans
# INFO:mini-rag:Getting node licenseUuid
# INFO:mini-rag:Getting node license
# INFO:mini-rag:Getting node SalableUnknownError
# INFO:mini-rag:Getting node Create License
# INFO:mini-rag:Extracted 11 excerpts for low-level entities.
# INFO:mini-rag:Getting edge ('granteeId', 'license')
# INFO:mini-rag:Getting edge ('license', 'uuid')
# INFO:mini-rag:Getting edge ('Create License', 'license')
# INFO:mini-rag:Getting edge ('license', 'your-license-uuid')
# INFO:mini-rag:Getting edge ('Licenses', 'updateLicense')
# INFO:mini-rag:Getting edge ('VersionHeader', 'updateLicense')
# INFO:mini-rag:Getting edge ('LicenseUpdateRequest', 'updateLicense')
# INFO:mini-rag:Getting edge ('Grantee', 'License')
# INFO:mini-rag:Getting edge ('License', 'Plan')
# INFO:mini-rag:Getting edge ('License', 'Salable Dashboard')
# INFO:mini-rag:Getting edge ('Grantee ID', 'License')
# INFO:mini-rag:Getting edge ('License', 'Update License')
# INFO:mini-rag:Getting edge ('License', 'Suspend License')
# INFO:mini-rag:Getting edge ('License', 'uuid')
# INFO:mini-rag:Getting edge ('License', 'status')
# INFO:mini-rag:Getting edge ('License', 'granteeId')
# INFO:mini-rag:Getting edge ('License', 'capabilities')
# INFO:mini-rag:Getting edge ('License', 'metadata')
# INFO:mini-rag:Getting edge ('License', 'Licenses Endpoint')
# INFO:mini-rag:Getting edge ('License', 'getLicenseByUuid')
# INFO:mini-rag:Getting edge ('License', 'cancelLicense')
# INFO:mini-rag:Getting edge ('License', 'getLicensesByGranteeId')
# INFO:mini-rag:Getting edge ('License', 'LicenseByPurchaser')
# INFO:mini-rag:Getting edge ('License', 'cancelLicenses')
# INFO:mini-rag:Getting edge ('Capabilities', 'LicenseByPurchaser')
# INFO:mini-rag:Getting edge ('LicenseByPurchaser', 'Plan')
# INFO:mini-rag:Getting edge ('LicenseByPurchaser', 'Subscription')
# INFO:mini-rag:Getting edge ('LicenseByPurchaser', 'Product')
# INFO:mini-rag:Getting edge ('LicenseByPurchaser', 'LicenseCount')
# INFO:mini-rag:Getting edge ('LicenseByPurchaser', 'getLicensesByPurchaser')
# INFO:mini-rag:Getting edge ('Bespoke Plans', 'License Type Section')
# INFO:mini-rag:Getting edge ('License Type Section', 'Standard Plans')
# INFO:mini-rag:Getting edge ('Coming Soon Plans', 'License Type Section')
# INFO:mini-rag:Getting edge ('Evaluation License', 'Grantee ID')
# INFO:mini-rag:Getting edge ('Evaluation License', 'Licensee Email')
# INFO:mini-rag:Getting edge ('Evaluation License', 'Product & Plan')
# INFO:mini-rag:Getting edge ('Create License Sidebar', 'Evaluation License')
# INFO:mini-rag:Getting edge ('Evaluation License', 'Expiration Date Parameter')
# INFO:mini-rag:Getting edge ('Update License', 'license object')
# INFO:mini-rag:Getting edge ('Create License', 'Salable')
# INFO:mini-rag:Getting edge ('Create License', 'CreateAdhocLicenseInput')
# INFO:mini-rag:Getting edge ('License check', 'getGrantee')
# INFO:mini-rag:Getting edge ('License check', 'capabilities')
# INFO:mini-rag:Getting edge ('CreateAdhocLicenseInput', 'Parameters')
# INFO:mini-rag:Getting edge ('Licenses', 'cancelLicense')
# INFO:mini-rag:Getting edge ('LicenseUuidPathParam', 'cancelLicense')
# INFO:mini-rag:Getting edge ('Get License Usage', 'License Usage Record')
# INFO:mini-rag:Getting edge ('License Usage Record', 'Update License Usage')
# INFO:mini-rag:Getting edge ('Cancel License', 'Salable')
# INFO:mini-rag:Getting edge ('Cancel License', 'licenseUuid')
# INFO:mini-rag:Getting edge ('Cancel License', 'cancel License Documentation')
# INFO:mini-rag:Getting edge ('Cancel License', 'TypeScript Code Sample')
# INFO:mini-rag:Getting edge ('Cancel License', 'cancel License API Endpoint')
# INFO:mini-rag:Getting edge ('Licenses', 'Salable')
# INFO:mini-rag:Getting edge ('Licenses', 'getOne')
# INFO:mini-rag:Getting edge ('Licenses', 'update')
# INFO:mini-rag:Getting edge ('Licenses', 'removeSeats')
# INFO:mini-rag:Getting edge ('Licenses', 'getCount')
# INFO:mini-rag:Getting edge ('Licenses', 'SalableResponseError')
# INFO:mini-rag:Getting edge ('Licenses', 'SalableValidationError')
# INFO:mini-rag:Getting edge ('Licenses', 'SalableUnknownError')
# INFO:mini-rag:Getting edge ('Create New License', 'Licenses')
# INFO:mini-rag:Getting edge ('Licenses', 'Product Page')
# INFO:mini-rag:Getting edge ('Left-Hand Menu', 'Licenses')
# INFO:mini-rag:Getting edge ('CursorPaginationLicensesResponse', 'Licenses')
# INFO:mini-rag:Getting edge ('Licenses', 'getLicensesCount')
# INFO:mini-rag:Getting edge ('Licenses', 'apiKey')
# INFO:mini-rag:Getting edge ('Licenses', 'getLicenseByUuid')
# ...
# INFO:mini-rag:Evaluation result for query 'What does the decrement option specify when removing subscription seats?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What does the decrement option specify when removing subscription seats?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What additional details can I find about the removal of subscription seats?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What additional details can I find about the removal of subscription seats?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What additional details can I find about the removal of subscription seats?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'Why is the UUID of the subscription necessary for retrieving switchable plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'Why is the UUID of the subscription necessary for retrieving switchable plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'Why is the UUID of the subscription necessary for retrieving switchable plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What should I refer to for detailed information regarding the request for switchable plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What should I refer to for detailed information regarding the request for switchable plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What should I refer to for detailed information regarding the request for switchable plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What happens to the subscription if the cancel option specifies "end"?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What happens to the subscription if the cancel option specifies "end"?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What happens to the subscription if the cancel option specifies "end"?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does returning the customer portal link benefit customers?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does returning the customer portal link benefit customers?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does returning the customer portal link benefit customers?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What should I do if I need more details about the Subscription Portal Link Object?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What should I do if I need more details about the Subscription Portal Link Object?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What should I do if I need more details about the Subscription Portal Link Object?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What additional details can I find in the API documentation regarding the Subscription update?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What additional details can I find in the API documentation regarding the Subscription update?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What additional details can I find in the API documentation regarding the Subscription update?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What can be done to a Subscription as indicated in the pull quote?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What can be done to a Subscription as indicated in the pull quote?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What can be done to a Subscription as indicated in the pull quote?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What can I do to find more details about changing a subscription's plan?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What can I do to find more details about changing a subscription's plan?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What can I do to find more details about changing a subscription's plan?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What does the function salable.pricingTables.getOne return?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What does the function salable.pricingTables.getOne return?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What does the function salable.pricingTables.getOne return?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can I create a session token for the checkout web component?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can I create a session token for the checkout web component?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can I create a session token for the checkout web component?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What should you specify in the 'success-url' property when using the Salable Checkout web component?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What should you specify in the 'success-url' property when using the Salable Checkout web component?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What should you specify in the 'success-url' property when using the Salable Checkout web component?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the significance of the subscription UUID in the context of displaying invoices?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the significance of the subscription UUID in the context of displaying invoices?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the significance of the subscription UUID in the context of displaying invoices?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the default number of rows displayed per page when using the invoices web component?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the default number of rows displayed per page when using the invoices web component?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the default number of rows displayed per page when using the invoices web component?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the purpose of the method described in the pull quote?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What is the purpose of the method described in the pull quote?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What is the purpose of the method described in the pull quote?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What parameter is crucial for defining the component that the created session will be associated with?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What parameter is crucial for defining the component that the created session will be associated with?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What parameter is crucial for defining the component that the created session will be associated with?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What can you tell me about the API documentation for the Event Object?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What can you tell me about the API documentation for the Event Object?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What can you tell me about the API documentation for the Event Object?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the method to unassign a license in the system?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the method to unassign a license in the system?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the method to unassign a license in the system?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What information does the capabilities property in the license check contain?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What information does the capabilities property in the license check contain?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What information does the capabilities property in the license check contain?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can the grace parameter be used to benefit users with licensing issues?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can the grace parameter be used to benefit users with licensing issues?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can the grace parameter be used to benefit users with licensing issues?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How do checkout links improve the payment process for users?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How do checkout links improve the payment process for users?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How do checkout links improve the payment process for users?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How are the seats allocated after a successful payment in the per-seat billing model?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'How are the seats allocated after a successful payment in the per-seat billing model?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'How are the seats allocated after a successful payment in the per-seat billing model?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What is the default setting for currency when accepting payments?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the default setting for currency when accepting payments?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is the default setting for currency when accepting payments?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can multiple licenses be cancelled simultaneously using the API?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can multiple licenses be cancelled simultaneously using the API?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can multiple licenses be cancelled simultaneously using the API?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can users cancel licenses using the cURL command?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can users cancel licenses using the cURL command?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can users cancel licenses using the cURL command?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can developers utilize the subscription seat information to enhance user experience?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can developers utilize the subscription seat information to enhance user experience?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can developers utilize the subscription seat information to enhance user experience?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can users check the availability of their subscription seats?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can users check the availability of their subscription seats?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can users check the availability of their subscription seats?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What is a common application of license data according to the information provided?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What is a common application of license data according to the information provided?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'What is a common application of license data according to the information provided?': 0/3 votes yes --> 0
# INFO:mini-rag:Evaluation result for query 'How does the process of adding seats differ between paid subscriptions and free plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does the process of adding seats differ between paid subscriptions and free plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does the process of adding seats differ between paid subscriptions and free plans?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'Why is it important to manage subscriptions through the Salable API instead of directly through Stripe?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'Why is it important to manage subscriptions through the Salable API instead of directly through Stripe?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'Why is it important to manage subscriptions through the Salable API instead of directly through Stripe?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does creating an ad hoc license provide flexibility in managing access?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does creating an ad hoc license provide flexibility in managing access?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How does creating an ad hoc license provide flexibility in managing access?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What does the second argument in the subscriptions.cancel function represent?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What does the second argument in the subscriptions.cancel function represent?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What does the second argument in the subscriptions.cancel function represent?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What happens to a subscription if it is cancelled with the 'end' option?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What happens to a subscription if it is cancelled with the 'end' option?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query "What happens to a subscription if it is cancelled with the 'end' option?": 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What options are available for canceling a subscription according to the pull quote?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What options are available for canceling a subscription according to the pull quote?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What options are available for canceling a subscription according to the pull quote?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What happens when a subscriber upgrades to a plan with a higher minimum seat requirement than their current subscription?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What happens when a subscriber upgrades to a plan with a higher minimum seat requirement than their current subscription?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'What happens when a subscriber upgrades to a plan with a higher minimum seat requirement than their current subscription?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can I obtain an "update payment method" link for a subscription using the Salable API?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can I obtain an "update payment method" link for a subscription using the Salable API?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation result for query 'How can I obtain an "update payment method" link for a subscription using the Salable API?': 3/3 votes yes --> 1
# INFO:mini-rag:Evaluation completed. Final accuracy score: 0.845
# 0.8446969696969697
